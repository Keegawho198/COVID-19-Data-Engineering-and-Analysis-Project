# %% [markdown]
# ## Import the dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Read the csv files

# %%
# read csv files and store into panadas DataFrame
countries_dataset = pd.read_csv("Resources/countries.csv")
countries_dataset.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
covid_cases_dataset = pd.read_csv("Resources/WHO COVID-19 cases.csv")
covid_cases_dataset.head()
# Out:
#   Date_reported Country_code      Country Continent WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0

# %%
#Rename columns in countries dataset
countries_dataset = countries_dataset.rename(columns ={'country':'Country_code','name':'Country'})
countries_dataset.head()
# Out:
#   Country_code   latitude  longitude               Country
# 0           AD  42.546245   1.601554               Andorra
# 1           AE  23.424076  53.847818  United Arab Emirates
# 2           AF  33.939110  67.709953           Afghanistan
# 3           AG  17.060816 -61.796428   Antigua and Barbuda
# 4           AI  18.220554 -63.068615              Anguilla

# %% [markdown]
# ### Merge the csv files to create a DataFrame

# %%
#Merge the datasets
complete_dataset = pd.merge(covid_cases_dataset, countries_dataset, on = ["Country_code", "Country_code"])
complete_dataset.head()
# Out:
#   Date_reported Country_code    Country_x Continent WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths  latitude  longitude  \
# 0                 0         NaN                  0  33.93911  67.709953
# 1                 0         NaN                  0  33.93911  67.709953
# 2                 0         NaN                  0  33.93911  67.709953
# 3                 0         NaN                  0  33.93911  67.709953
# 4                 0         NaN                  0  33.93911  67.709953
#
#      Country_y
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %% [markdown]
# ### Clean the DataFrame

# %%
#drop unneccessary columns
complete_dataset = complete_dataset.drop(columns={"Country_y"})
complete_dataset.head()
# Out:
#   Date_reported Country_code    Country_x Continent WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths  latitude  longitude
# 0                 0         NaN                  0  33.93911  67.709953
# 1                 0         NaN                  0  33.93911  67.709953
# 2                 0         NaN                  0  33.93911  67.709953
# 3                 0         NaN                  0  33.93911  67.709953
# 4                 0         NaN                  0  33.93911  67.709953

# %%
#rename the columns
complete_dataset = complete_dataset.rename(columns={"Date_reported":"Date","Country_code":"Country Code","Country_x":"Country","WHO_region":"WHO Region",
                                                    "New_cases":"New Cases","Cumulative_cases":"Cumulative Cases","New_deaths":"New Deaths","Cumulative_deaths":"Cumulative Deaths",
                                                    "latitude":"Latitude","longitude":"Longtitude"})
complete_dataset.head()
# Out:
#          Date Country Code      Country Continent WHO Region  New Cases  \
# 0  2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1  2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2  2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3  2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4  2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
#
#    Cumulative Cases  New Deaths  Cumulative Deaths  Latitude  Longtitude
# 0                 0         NaN                  0  33.93911   67.709953
# 1                 0         NaN                  0  33.93911   67.709953
# 2                 0         NaN                  0  33.93911   67.709953
# 3                 0         NaN                  0  33.93911   67.709953
# 4                 0         NaN                  0  33.93911   67.709953

# %%
#identify emty and Nan rows
complete_dataset.count()
# Out:
# Date                 55632
# Country Code         55388
# Country              55632
# Continent            55632
# WHO Region           51728
# New Cases            38384
# Cumulative Cases     55632
# New Deaths           24845
# Cumulative Deaths    55632
# Latitude             55632
# Longtitude           55632
# dtype: int64

# %%
#drop incomplete rows
complete_dataset=complete_dataset.dropna(how ='any')

#verify all the incomplete values removed
complete_dataset.count()
# Out:
# Date                 23771
# Country Code         23771
# Country              23771
# Continent            23771
# WHO Region           23771
# New Cases            23771
# Cumulative Cases     23771
# New Deaths           23771
# Cumulative Deaths    23771
# Latitude             23771
# Longtitude           23771
# dtype: int64

# %% [markdown]
# ### Check and update the datatype

# %%
#check the datatypes
complete_dataset.dtypes
# Out:
# Date                  object
# Country Code          object
# Country               object
# Continent             object
# WHO Region            object
# New Cases            float64
# Cumulative Cases       int64
# New Deaths           float64
# Cumulative Deaths      int64
# Latitude             float64
# Longtitude           float64
# dtype: object

# %%
#change date data types
complete_dataset['Date'] = pd.to_datetime(complete_dataset['Date'])

#check if date datatypes changes
complete_dataset.dtypes
# Out:
# Date                 datetime64[ns]
# Country Code                 object
# Country                      object
# Continent                    object
# WHO Region                   object
# New Cases                   float64
# Cumulative Cases              int64
# New Deaths                  float64
# Cumulative Deaths             int64
# Latitude                    float64
# Longtitude                  float64
# dtype: object

# %%
#Export the clean dataset
# complete_dataset.to_csv('output_Amrit/complete_Dataset.csv', index = False)

# %% [markdown]
# ## Countries and Continents DataFrames

# %% [markdown]
# #### Countries

# %%
#Create a new dataframe to store 'country_code'and  'country' 
country = complete_dataset['Country'].unique()
country_code= complete_dataset['Country Code'].unique()

# %%
#Check the data length
print(len(country))
print(len(country_code))
# Out:
# 207
# 207

# %%
#Export the Countries dataframe
Countries_df= pd.DataFrame({'Country Code':country_code, 'Country':country, })

# print the sample Dataframe
Countries_df.head()
# Out:
#   Country Code         Country
# 0           AF     Afghanistan
# 1           AL         Albania
# 2           DZ         Algeria
# 3           AS  American Samoa
# 4           AD         Andorra

# %%
#Check the Datatype and convert the datatype appropriately
Countries_df.dtypes
# Out:
# Country Code    object
# Country         object
# dtype: object

# %%
#Export the Dataframe as a csv file
Countries_df.to_csv('output_Amrit/Countries.csv', index = False)

# %% [markdown]
# ### Continents

# %%
#Create a new dataframe to store 'continent' and 'WHO Regions'
continent=complete_dataset['Continent'].unique()
WHO= complete_dataset['WHO Region'].unique()

# %%
#Create Geographic dataset 
Geo_df= pd.DataFrame({'Continents':continent, 'WHO Region':WHO})
Geo_df.head()

# %%
#Check the datatype
Geo_df.dtypes
# Out:
# Continents    object
# WHO Region    object
# dtype: object

# %%
#Export the dataframe
Geo_df.to_csv('output_Amrit/Continents.csv', index = False)

# %% [markdown]
# ### Create the Patient Database to record all Covid cases and deaths associated with it

# %%
#Create the dataframe
Patient_database= pd.DataFrame(
    {'Date':complete_dataset['Date'],
     'Country Code':complete_dataset['Country Code'],
     'WHO Region':complete_dataset['WHO Region'],
     'New Cases':complete_dataset['New Cases'],
     'Cumulative Cases':complete_dataset['Cumulative Cases'],
     'New Deaths':complete_dataset['New Deaths'],
     'Cumulative Deaths':complete_dataset['Cumulative Deaths'
     ]})

#Clean the dataframe
Patient_database=Patient_database.dropna(how ='any')

# Print the sample  dataframe
Patient_database.head()
# Out:
#          Date Country Code WHO Region  New Cases  Cumulative Cases  \
# 12 2020-03-29           AF       EMRO       67.0                91
# 13 2020-04-05           AF       EMRO      183.0               274
# 14 2020-04-12           AF       EMRO      247.0               521
# 15 2020-04-19           AF       EMRO      387.0               908
# 16 2020-04-26           AF       EMRO      422.0              1330
#
#     New Deaths  Cumulative Deaths
# 12         2.0                  2
# 13         3.0                  5
# 14        10.0                 15
# 15        15.0                 30
# 16        13.0                 43

# %%
#Check the datatype
Patient_database.dtypes
# Out:
# Date                 datetime64[ns]
# Country Code                 object
# WHO Region                   object
# New Cases                   float64
# Cumulative Cases              int64
# New Deaths                  float64
# Cumulative Deaths             int64
# dtype: object

# %%
#Export the patients dataset
Patient_database.to_csv('output_Amrit/Patient_database.csv', index = False)

# %% [markdown]
# ### Coordinates

# %%
# Creaye Coordinates dataframe
coordinates_df= pd.DataFrame(
    {
     'Country Code':complete_dataset['Country Code'].unique(),
     'Longitude':complete_dataset[ 'Longtitude'].unique(),
     'Latitude':complete_dataset['Latitude'].unique()
     })

coordinates_df.head()
# Out:
#   Country Code   Longitude   Latitude
# 0           AF   67.709953  33.939110
# 1           AL   20.168331  41.153332
# 2           DZ    1.659626  28.033886
# 3           AS -170.132217 -14.270972
# 4           AD    1.601554  42.546245

# %%
#Check the dataype
coordinates_df.dtypes
# Out:
# Country Code     object
# Longitude       float64
# Latitude        float64
# dtype: object

# %%
#Export the patients dataset
coordinates_df.to_csv('output_Amrit/coordinates_df.csv', index = False)

# %% [markdown]
# ### Database Analysis

# %%
#aggregation: group by country
country_group_data = complete_dataset.groupby('Country').agg({
    'New Cases':['sum', 'mean'],
    'New Deaths':['sum','mean']
})
country_group_data.head()
# Out:
#                New Cases              New Deaths
#                      sum         mean        sum       mean
# Country
# Afghanistan     235214.0  1078.963303     7998.0  40.190955
# Albania         335047.0  1772.735450     3605.0  27.730769
# Algeria         272156.0  1283.754717     6881.0  61.990991
# American Samoa    8359.0   144.120690       34.0   3.090909
# Andorra          48015.0   303.892405      159.0   2.606557

# %%
#use aggregation to find the max,min cases and deaths all over the world
country_stats = complete_dataset.groupby('Country').agg({
    'Cumulative Cases': 'max',  
    'Cumulative Deaths': 'max'  
}).reset_index()

# Find the country with maximum cases
max_cases_country = country_stats.loc[country_stats['Cumulative Cases'].idxmax()]

# Find the country with minimum cases
min_cases_country = country_stats.loc[country_stats['Cumulative Cases'].idxmin()]

# Find the country with maximum deaths
max_deaths_country = country_stats.loc[country_stats['Cumulative Deaths'].idxmax()]

# Find the country with minimum deaths
min_deaths_country = country_stats.loc[country_stats['Cumulative Deaths'].idxmin()]

# Display Results
print("Country with Maximum Cases:", max_cases_country)
print("\nCountry with Minimum Cases:", min_cases_country)
print("\nCountry with Maximum Deaths:", max_deaths_country)
print("\nCountry with Minimum Deaths:", min_deaths_country)
# Out:
# Country with Maximum Cases: Country              United States of America
# Cumulative Cases                    103436829
# Cumulative Deaths                     1127152
# Name: 196, dtype: object
#
# Country with Minimum Cases: Country              Montserrat
# Cumulative Cases           1003
# Cumulative Deaths             8
# Name: 124, dtype: object
#
# Country with Maximum Deaths: Country              United States of America
# Cumulative Cases                    103436829
# Cumulative Deaths                     1127152
# Name: 196, dtype: object
#
# Country with Minimum Deaths: Country              Nauru
# Cumulative Cases      3970
# Cumulative Deaths        1
# Name: 128, dtype: object

# %%
#correlation between new cases and new deaths
correlation = complete_dataset[['New Cases', 'New Deaths', 'Cumulative Cases', 'Cumulative Deaths']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#filter by country Australia
australia_data = complete_dataset[complete_dataset['Country'] == 'Australia']

australia_data.head()
# Out:
#            Date Country Code    Country Continent WHO Region  New Cases  \
# 2693 2020-03-08           AU  Australia   Oceania       WPRO       45.0
# 2694 2020-03-15           AU  Australia   Oceania       WPRO      179.0
# 2695 2020-03-22           AU  Australia   Oceania       WPRO      832.0
# 2696 2020-03-29           AU  Australia   Oceania       WPRO     2728.0
# 2697 2020-04-05           AU  Australia   Oceania       WPRO     1826.0
#
#       Cumulative Cases  New Deaths  Cumulative Deaths   Latitude  Longtitude
# 2693                70         4.0                  4 -25.274398  133.775136
# 2694               249         3.0                  7 -25.274398  133.775136
# 2695              1081         2.0                  9 -25.274398  133.775136
# 2696              3809         7.0                 16 -25.274398  133.775136
# 2697              5635        20.0                 36 -25.274398  133.775136

# %%
 #Calculate the average new cases in total in Australia
average_cases = australia_data['New Cases'].mean()
print(f"Average COVID-19 cases in Australia: {average_cases:.2f}")

# Find the day with maximum cases
max_cases_day = australia_data.loc[australia_data['New Cases'].idxmax()]
print(f"Maximum cases: {max_cases_day['New Cases']} on {max_cases_day['Date'].date()}")

# Find the day with minimum cases
min_cases_day = australia_data.loc[australia_data['New Cases'].idxmin()]
print(f"Minimum cases: {min_cases_day['New Cases']} on {min_cases_day['Date'].date()}")

# Find the day with maximum deaths
max_deaths_day = australia_data.loc[australia_data['New Deaths'].idxmax()]
print(f"Maximum deaths: {max_deaths_day['New Deaths']} on {max_deaths_day['Date'].date()}")

# Find the day with minimum deaths
min_deaths_day = australia_data.loc[australia_data['New Deaths'].idxmin()]
print(f"Minimum deaths: {min_deaths_day['New Deaths']} on {min_deaths_day['Date'].date()}")
# Out:
# Average COVID-19 cases in Australia: 64275.34
# Maximum cases: 588813.0 on 2022-01-09
# Minimum cases: 28.0 on 2021-02-21
# Maximum deaths: 1161.0 on 2023-02-05
# Minimum deaths: -76.0 on 2023-07-23

# %%
#using pivot_table() for summarised the data. this is new not used in the class
pivot_summary = australia_data.pivot_table(
    index='Date', values=['New Cases', 'New Deaths'], aggfunc='sum'
)
pivot_summary
# Out:
#             New Cases  New Deaths
# Date
# 2020-03-08       45.0         4.0
# 2020-03-15      179.0         3.0
# 2020-03-22      832.0         2.0
# 2020-03-29     2728.0         7.0
# 2020-04-05     1826.0        20.0
# ...               ...         ...
# 2024-04-21     4424.0        34.0
# 2024-04-28     4657.0        21.0
# 2024-05-05     4866.0        16.0
# 2024-05-12     6769.0        18.0
# 2024-05-19     8003.0        16.0
#
# [181 rows x 2 columns]

# %%
# Scatter Plot: New Cases vs New Deaths
plt.figure(figsize=(8, 6))
sns.scatterplot(data=complete_dataset, x='New Cases', y='New Deaths', color='red', s=100)
plt.title('Scatter Plot of New Cases vs New Deaths', fontsize=16)
plt.xlabel('New Cases', fontsize=14)
plt.ylabel('New Deaths', fontsize=14)
plt.grid()
plt.show()

# %%
complete_dataset.head()
# Out:
#          Date Country Code      Country Continent WHO Region  New Cases  \
# 12 2020-03-29           AF  Afghanistan      Asia       EMRO       67.0
# 13 2020-04-05           AF  Afghanistan      Asia       EMRO      183.0
# 14 2020-04-12           AF  Afghanistan      Asia       EMRO      247.0
# 15 2020-04-19           AF  Afghanistan      Asia       EMRO      387.0
# 16 2020-04-26           AF  Afghanistan      Asia       EMRO      422.0
#
#     Cumulative Cases  New Deaths  Cumulative Deaths  Latitude  Longtitude
# 12                91         2.0                  2  33.93911   67.709953
# 13               274         3.0                  5  33.93911   67.709953
# 14               521        10.0                 15  33.93911   67.709953
# 15               908        15.0                 30  33.93911   67.709953
# 16              1330        13.0                 43  33.93911   67.709953
